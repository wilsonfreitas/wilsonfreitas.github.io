# %%
import vincent

# %%
import ggplot
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-1140326dc452> in <module>()
# ----> 1 import ggplot
#
# /Users/wilson/Dev/aw/blog/lib/python2.7/site-packages/ggplot/__init__.py in <module>()
#      19 __version__ = '0.5.8'
#      20
# ---> 21 from .qplot import qplot
#      22 from .ggplot import ggplot
#      23 from .components import aes
#
# /Users/wilson/Dev/aw/blog/lib/python2.7/site-packages/ggplot/qplot.py in <module>()
#       3
#       4 import ggplot
# ----> 5 from .components import aes
#       6 from .geoms import geom_point, geom_bar, geom_histogram, geom_line
#       7 from .geoms.chart_components import xlab as xlabel
#
# /Users/wilson/Dev/aw/blog/lib/python2.7/site-packages/ggplot/components/__init__.py in <module>()
#       2                         unicode_literals)
#       3 from .aes import aes
# ...
